# %% [markdown]
# <a href="https://colab.research.google.com/github/developer2905/Prodigy_DS_05/blob/main/Task_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'accidents.csv')

# %%
df
# Out:
#       AccidentDate     Timing           State WeatherCondition  \
# 0       04-02-2013    Morning          Alaska            Rainy
# 1       23-02-2005      Night         Arizona            Clear
# 2       08-10-2014  Afternoon      California            Clear
# 3       14-01-2015      Night        Colorado            Rainy
# 4       17-01-2006  Afternoon         Georgia            Clear
# ...            ...        ...             ...              ...
# 49995   20-08-2002      Night        Virginia            Clear
# 49996   15-05-2012      Night        Virginia            Clear
# 49997   19-05-2007    Evening  North Carolina            Rainy
# 49998   04-08-2019      Night  South Carolina            Clear
# 49999   25-04-2019    Evening         Georgia            Rainy
#
#             RoadCondition  Deaths              Reason
# 0      Under Construction      10       Drunk Driving
# 1      Under Construction       3  Weather Conditions
# 2                    Fine       6     Poor Visibility
# 3                   Rough       8     Road Conditions
# 4                    Fine       2            Speeding
# ...                   ...     ...                 ...
# 49995  Under Construction       2  Mechanical Failure
# 49996  Under Construction       0  Mechanical Failure
# 49997  Under Construction       2      Driver Fatigue
# 49998                Fine       0  Distracted Driving
# 49999                Fine       2  Weather Conditions
#
# [50000 rows x 7 columns]

# %%
# @title WeatherCondition

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('WeatherCondition').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.head()
# Out:
#   AccidentDate     Timing       State WeatherCondition       RoadCondition  \
# 0   04-02-2013    Morning      Alaska            Rainy  Under Construction
# 1   23-02-2005      Night     Arizona            Clear  Under Construction
# 2   08-10-2014  Afternoon  California            Clear                Fine
# 3   14-01-2015      Night    Colorado            Rainy               Rough
# 4   17-01-2006  Afternoon     Georgia            Clear                Fine
#
#    Deaths              Reason
# 0      10       Drunk Driving
# 1       3  Weather Conditions
# 2       6     Poor Visibility
# 3       8     Road Conditions
# 4       2            Speeding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AccidentDate      50000 non-null  object
#  1   Timing            50000 non-null  object
#  2   State             50000 non-null  object
#  3   WeatherCondition  50000 non-null  object
#  4   RoadCondition     50000 non-null  object
#  5   Deaths            50000 non-null  int64
#  6   Reason            50000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#              Deaths
# count  50000.000000
# mean       4.983040
# std        3.160581
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000

# %%
df.columns
# Out:
# Index(['AccidentDate', 'Timing', 'State', 'WeatherCondition', 'RoadCondition',
#        'Deaths', 'Reason'],
#       dtype='object')

# %%
df.AccidentDate.unique()
# Out:
# array(['04-02-2013', '23-02-2005', '08-10-2014', ..., '22-06-2013',
#        '20-02-2022', '21-10-2018'], dtype=object)

# %%
df.Timing.unique()
# Out:
# array(['Morning', 'Night', 'Afternoon', 'Evening'], dtype=object)

# %%
df.State.unique()
# Out:
# array(['Alaska', 'Arizona', 'California', 'Colorado', 'Georgia',
#        'Indiana', 'Louisiana', 'Nevada', 'Montana', 'New Jersey',
#        'New Mexico', 'New York', 'Ohio', 'Pennsylvania', 'Texas',
#        'Virginia', 'Washington', 'North Carolina', 'South Carolina',
#        'Wisconsin', 'Wyoming', 'West Virginia', 'Florida', 'Vermont',
#        'Michigan', 'Minnesota', 'Illinois', 'Iowa'], dtype=object)

# %%
df.WeatherCondition.unique()
# Out:
# array(['Rainy', 'Clear', 'Foggy'], dtype=object)

# %%
df.RoadCondition.unique()
# Out:
# array(['Under Construction', 'Fine', 'Rough'], dtype=object)

# %%
df.Deaths.unique()
# Out:
# array([10,  3,  6,  8,  2,  4,  0,  5,  1,  9,  7])

# %%
df.Reason.unique()
# Out:
# array(['Drunk Driving', 'Weather Conditions', 'Poor Visibility',
#        'Road Conditions', 'Speeding', 'Reckless Driving',
#        'Distracted Driving', 'Driver Fatigue', 'Mechanical Failure'],
#       dtype=object)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="State", data=df, order=df['State'].value_counts().index,palette='icefire') # Added DataFrame to data parameter
plt.title("Distribution of Accidents Across States")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# <ipython-input-19-7004b638a92a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="State", data=df, order=df['State'].value_counts().index,palette='icefire') # Added DataFrame to data parameter

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x="RoadCondition", data=df, order=df['RoadCondition'].value_counts().index,palette='pastel')
plt.title("Accidents Based on Road Conditions")
plt.show()
# Out:
# <ipython-input-20-3c0f082cf195>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="RoadCondition", data=df, order=df['RoadCondition'].value_counts().index,palette='pastel')

# %%
timing_counts = df['Timing'].value_counts()
colors = plt.cm.tab20.colors[:len(timing_counts)]

plt.figure(figsize=(8, 6))
plt.pie(timing_counts, labels=timing_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Accidents Based on Timing of the Day")
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x="WeatherCondition", hue="Timing", data=df, order=df['WeatherCondition'].value_counts().index,palette='flare')
plt.title("Accidents by Weather Conditions and Timing of the Day")
plt.show()

# %%
plt.figure(figsize=(12, 6))
reasons_accidents = df['Reason'].value_counts()
sns.barplot(x=reasons_accidents.index, y=reasons_accidents.values, palette="BrBG")
plt.title("Reason for Accidents")
plt.xlabel("Reason")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# <ipython-input-24-0d94bfa2ecbe>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=reasons_accidents.index, y=reasons_accidents.values, palette="BrBG")

# %%
sns.set(style="whitegrid")


state_timingdeaths = df.groupby(['State', 'Timing'])['Deaths'].sum().reset_index()


state_timingdeaths_pivot = state_timingdeaths.pivot(index='State', columns='Timing', values='Deaths').fillna(0)


plt.figure(figsize=(50, 10))
state_timingdeaths_pivot.plot(kind='bar', stacked=True, colormap="icefire")
plt.title("Death Timing Ratio")
plt.xlabel("State")
plt.ylabel("Total Deaths")
plt.xticks(rotation=90, ha="right")
plt.legend(title="Timing")
plt.show()
